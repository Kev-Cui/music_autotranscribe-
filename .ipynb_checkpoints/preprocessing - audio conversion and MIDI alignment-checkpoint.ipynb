# %%
from pydub import AudioSegment

# %%
mp3_file_path = "piano_mp3/alb_esp2.mp3"

audio = AudioSegment.from_mp3(mp3_file_path)

# %%
audio.frame_rate
# Out:
# 44100

# %%
import numpy as np

audio_waveform = np.frombuffer(audio.raw_data, dtype=np.int16)

# %%
from scipy.signal import spectrogram
import matplotlib.pyplot as plt

# Compute the spectrogram
f, t, Sxx = spectrogram(audio_waveform, fs=audio.frame_rate)

# Plot the spectrogram
plt.figure(figsize=(10, 4))
plt.pcolormesh(t, f, 10 * np.log10(Sxx))
plt.title("Spectrogram")
plt.xlabel("Time (s)")
plt.ylabel("Frequency (Hz)")
plt.colorbar(label="dB")
plt.show()
# Out:
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_23076\2515962096.py:9: RuntimeWarning: divide by zero encountered in log10
#   plt.pcolormesh(t, f, 10 * np.log10(Sxx))

# %%
import pretty_midi

midi_file = "path/to/your/midi_file.mid"
midi_data = pretty_midi.PrettyMIDI(midi_file)

# Extract note events (onsets, offsets, pitches)
for instrument in midi_data.instruments:
    for note in instrument.notes:
        onset_time = note.start
        offset_time = note.end
        pitch = note.pitch
        # Align this information with the spectrogram frames
        # (map time to spectrogram bins)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import pretty_midi
#       3 midi_file = "path/to/your/midi_file.mid"
#       4 midi_data = pretty_midi.PrettyMIDI(midi_file)
#
# ModuleNotFoundError: No module named 'pretty_midi'
